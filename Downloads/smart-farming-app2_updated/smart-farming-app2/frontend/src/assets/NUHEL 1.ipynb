# %% [markdown]
# # **Big Data Analytics [CN7031] CRWK 2025-26**
#
#
# # **Group ID: [Your Group ID]**
# 1.   Student 1: Name and ID
# 2.   Student 2: Name and ID
# 3.   Student 3: Name and ID
# 4.   Student 4: Name and ID
#
# ---
#
#
# If you want to add comments on your group work, please write it here for us:

# %% [markdown]
# # **Initiate and Configure Spark**
#
# ---

# %%
# !pip3 install pyspark

# %%
# linking with Spark

# %% [markdown]
# # **Data Acquisition & Cleaning: HuggingFace Data [10 marks]**
#
# ---

# %%
# Your code here. If you have more than one Data, add more code cells accordingly.

# %% [markdown]
# # **Student 1: (Name and ID)**
#
# ## The chosen technical tasks 1–4 [each task is worth 20 marks, totaling 80 marks]
#
# ---

# %%
# Your chosen task 1: ID and Task Description

# %%
# Your chosen task 2: ID and Task Description

# %%
# Your chosen task 3: ID and Task Description

# %%
# Your chosen task 4: ID and Task Description

# %% [markdown]
# # **Student 2: (Name and ID)**
#
# ## The chosen technical tasks 1–4 [each task is worth 20 marks, totaling 80 marks]
#
# ---

# %%
# Your chosen task 1: ID and Task Description

# %%
# Your chosen task 2: ID and Task Description

# %%
# Your chosen task 3: ID and Task Description

# %%
# Your chosen task 4: ID and Task Description

# %% [markdown]
# # **Student 3: (Name and ID)**
#
# ## The chosen technical tasks 1–4 [each task is worth 20 marks, totaling 80 marks]
#
# ---

# %%
# Your chosen task 1: ID and Task Description

# %%
# Your chosen task 2: ID and Task Description

# %%
# Your chosen task 3: ID and Task Description

# %%
# Your chosen task 4: ID and Task Description

# %% [markdown]
# # **Student 4: (Name and ID)**
#
# ## The chosen technical tasks 1–4 [each task is worth 20 marks, totaling 80 marks]
#
# ---

# %%
# Your chosen task 1: ID and Task Description

# %%
# Your chosen task 2: ID and Task Description

# %%
# Your chosen task 3: ID and Task Description

# %%
# Your chosen task 4: ID and Task Description

# %% [markdown]
# # **Convert ipynb to HTML for Turnitin submission [10 marks]**
# Individual contributions are clearly well-structured, professionally formatted, and adheres to academic conventions. Clear, error-free language and technical terminology.
#
# ---

# %%
# install nbconvert
#!pip3 install nbconvert


# convert ipynb to html
# file name: "Your_Group_ID_CN7031.ipynb
# !jupyter nbconvert --to html Your_Group_ID_CN7031.ipynb
